# %%
from transformers import pipeline

# Load the classification pipeline with the specified model
pipe = pipeline("text-classification",
                model="tabularisai/multilingual-sentiment-analysis")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/851 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Device set to use cpu

# %%
# Classify a new sentence
#sentence = "I love this product! It's amazing and works perfectly."
sentence = "The food was not so good."
result = pipe(sentence)

# Print the result
print(result)
# Out:
# [{'label': 'Negative', 'score': 0.9237943887710571}]

# %%
from transformers import pipeline
sentiment = pipeline("sentiment-analysis")
sentiment("I love this!")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9998764991760254}]

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
text = """
AI is moving fast and it’s more than hype. As advancements in agentic AI present significant opportunities for organizations, this report breaks down the most critical AI trends that will reshape how software is developed, deployed, and scaled.

Whether you're building internal applications or transforming customer experiences, now is the time to understand which AI innovations are worth investing in and how to strategically prepare your tech stack for what’s coming.

Actionable insights for IT and business leaders
Uncover the key technologies and trends that will define how AI is used across the software development lifecycle. Learn how to adapt your strategy, prioritize the right tools, and prepare your teams for the next wave of innovation.

As you read this report, we recommend you consider our following key takeaways:

How advanced AI is driving automation, problem-solving, and decision-making across industries.
Ways agentic AI will create significant opportunities to improve productivity, customer experience, and decision-making, but it will require user trust to gain sustained adoption.
Strategies for managing AI risks, compliance, and responsible adoption.
Key insights on where AI is headed and how to build a competitive advantage.
Gartner, Emerging Tech Impact Radar: Generative AI, Annette Zimmermann, Danielle Casey, 14 February 2025. GARTNER is a registered trademark and service mark of Gartner, Inc. and/or its affiliates in the U.S. and internationally and is used herein with permission. All rights reserved.
"""

print(summarizer(text , max_length = 100)[0]['summary_text'])
# Out:
# AI is moving fast and it’s more than hype. As advancements in agentic AI present significant opportunities for organizations. This report breaks down the most critical AI trends that will reshape how software is developed, deployed, and scaled. Now is the time to understand which AI innovations are worth investing in and how to strategically prepare your tech stack.

# %% [markdown]
# **Text Generation**

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
output = generator("In the future, artificial intelligence will",
                   max_length = 30,
                   num_return_sequences = 5)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(output[0])
# Out:
# {'generated_text': "In the future, artificial intelligence will go after other things, from food as medicine to the construction of new roads. We will see a complete transformation of our societies.\n\nYou're a computer scientist. What are your thoughts on the future of artificial intelligence?\n\nI'm very optimistic about the future of artificial intelligence, because the technology can be used in many different ways. The first is that it can be used to improve the way we think. But it also brings a lot of useful properties. For example, it's possible to create artificial intelligence that is completely different from the human brain, because there is no one thing that you can do with an artificial intelligence, including making it smarter.\n\nYou're a computer scientist. What are your thoughts on the future of artificial intelligence?\n\nI am very optimistic about the future of artificial intelligence, because the technology can be used in many different ways. The first is that it 
# ...

# %%
print(output[1])
# Out:
# {'generated_text': "In the future, artificial intelligence will be able to do this. So we'll see if it can do it in the near future.\n\nAre you excited about this prospect? Do you think it will become a reality? Let us know in the comment section below."}

# %%
print(output[2])
# Out:
# {'generated_text': 'In the future, artificial intelligence will be able to pick up the pieces of the puzzle.\n\n"We\'ll be able to go from that to the next level of machine learning," said Robert Schumann, a professor at Harvard University and the lead author of the paper, which was published in the Proceedings of the National Academy of Sciences.\n\nThe paper is based on research that showed that "smart" computers can learn to identify handwritten signatures, and the work of other scientists has shown that artificial intelligence can learn quickly to identify handwritten signatures.\n\nSome of the techniques that might help, such as the use of a special kind of computer to do a task, may be too complex to carry out in humans.\n\nIn the future, researchers will need to develop and implement a computer program that can recognize handwriting, Schumann said.\n\nHe said his team will also be working with others to build artificial intelligence that can recognize handwritten signatures.\n
# ...

# %%
print(output[3])
# Out:
# {'generated_text': 'In the future, artificial intelligence will become a major technology.\n\n"That\'s what this is going to bring," said Chris A. Moore, who leads the research group at Stanford University and is a professor of computer science. "What it will bring is a sense of control of the world that is going to be very powerful and hard to change. It\'ll eventually allow people to be more productive and more able to be creative."\n\nResearchers also will be able to design algorithms to make their own choices in their lives.\n\n"If there is a human that can choose the right way to live and make decisions and that is able to pick the right relationship, that\'s going to be more productive for people," said David B. Pizarro, a Stanford University computer scientist and co-author of the paper. "It will enable us to make smarter decisions."\n\nThe researchers will work with companies like Google and Facebook to develop autonomous cars. They will also develop and test algorithms to pr
# ...

# %%
print(output[4])
# Out:
# {'generated_text': 'In the future, artificial intelligence will have to do a lot of work to get it to learn how to deal with human thoughts.\n\nHere\'s the thing: AI is not something that\'s going to be invented overnight. It won\'t be created overnight. It\'s going to be something that people are going to have to do from day one.\n\nWhat we need is an AI that can sort of interact with the way people do things, and then act as if they\'re human.\n\nWe need a computer with a lot of personality and a lot of social skills. And we need a computer that can sort of do that.\n\nThat\'s the big challenge.\n\nAnd that\'s the big problem, because AI is a very diverse field. It\'s not just a very simple problem. It\'s a very complex problem.\n\nThat\'s why I think it\'s so important to have artificial intelligence as a sort of "safe haven" for humans in the field. To start to think about what\'s going on.\n\nAnd then to understand how it\'s going to work, to understand how it\'s going to work.\
# ...

# %% [markdown]
# **GPT_OSS_20b**

# %%
from transformers import pipeline
import torch

model_id = "openai/gpt-oss-20b"

pipe = pipeline(
    "text-generation",
    model=model_id)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# MXFP4 quantization requires Triton and kernels installed: CUDA requires Triton >= 3.4.0, XPU requires Triton >= 3.5.0, we will default to dequantizing the model to bf16
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00000-of-00002.safetensors:   0%|          | 0.00/4.79G [00:00<?, ?B/s]
# ...
